# %%
import glob
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing.image import load_img, img_to_array, array_to_img 
from keras.models import load_model
import model_evaluation_utils as meu

# %%
t1_img_aug_cnn = load_model('cats_dogs_tlearn_finetune_img_aug_cnn.h5')

# %%
IMG_DIM = (150,150)
input_shape = (150,150,3)
num2class_label_transformer = lambda l:['cat' if x==0 else 'dog' for x in l]
class2num_label_transformer = lambda l:[0 if x=='cat' else 1 for x in l]

# %% [markdown]
# load sample image

# %%
import matplolib.pyplot as plt

# %%
sample_img_path = '/Users/juansantateresagomez/Documents/Transfer_learning/layed_cat.jpg'
sample_img = load_img(sample_img_path, target_size=IMG_DIM)
sample_img_tensor = img_to_array(sample_img)

# %%
sample_img_tensor = np.expand_dims(sample_img_tensor, axis=0)

# %%
sample_img_tensor /=255

# %%
sample_img_tensor
# Out:
# array([[[[0.5058824 , 0.5568628 , 0.5803922 ],
#          [0.45490196, 0.49803922, 0.52156866],
#          [0.4509804 , 0.49411765, 0.5176471 ],
#          ...,
#          [0.50980395, 0.5137255 , 0.53333336],
#          [0.40784314, 0.43529412, 0.45882353],
#          [0.44313726, 0.47058824, 0.49411765]],
#
#         [[0.4862745 , 0.5372549 , 0.56078434],
#          [0.50980395, 0.5529412 , 0.5764706 ],
#          [0.49411765, 0.5372549 , 0.56078434],
#          ...,
#          [0.44705883, 0.4509804 , 0.47058824],
#          [0.3647059 , 0.39215687, 0.41568628],
#          [0.39607844, 0.42352942, 0.44705883]],
#
#         [[0.43137255, 0.48235294, 0.5058824 ],
#          [0.5568628 , 0.6       , 0.62352943],
#          [0.5568628 , 0.6       , 0.62352943],
#          ...,
#          [0.50980395, 0.5137255 , 0.53333336],
#          [0.4509804 , 0.46666667, 0.47843137],
#          [0.45882353, 0.4745098 , 0.4862745 ]],
#
#         ...,
#
# ...

# %%
print(sample_img_tensor.shape)
# Out:
# (1, 150, 150, 3)

# %%
plt.imshow(sample_img_tensor[0])

# %%
tlearn_cnn_img_aug_prediction = num2class_label_transformer(t1_img_aug_cnn.predict_classes(
sample_img_tensor, verbose=0))
# Out:
# /Users/juansantateresagomez/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
print(tlearn_cnn_img_aug_prediction)
# Out:
# ['cat']

# %%
sample_img_path_2 = '/Users/juansantateresagomez/Documents/Transfer_learning/layed_dog.jpg'
sample_img_2 = load_img(sample_img_path_2, target_size=IMG_DIM)

# %%
sample_img_tensor_2 = img_to_array(sample_img_2)

# %%
sample_img_tensor_2 = np.expand_dims(sample_img_tensor_2, axis = 0)
sample_img_tensor_2 /= 255

# %%
sample_img_tensor_2.shape
# Out:
# (1, 150, 150, 3)

# %%
plt.imshow(sample_img_tensor_2[0])
